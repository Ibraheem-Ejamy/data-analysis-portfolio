# %% [markdown]
# <center><img src="redpopcorn.jpg"></center>

# %% [markdown]
# # Investigating Netflix Movies from the 1990s 🎥
#
# Welcome!
# In this project, we'll explore Netflix's collection of movies from the 1990s.
# We'll dive into movie release trends, durations, and genre patterns to uncover insights about one of the most nostalgic decades in entertainment.
#
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex my exploratory data analysis skills and dive into the entertainment industry.
#
#
# The dataset `netflix_data.csv`, have the following table detailing the column names and descriptions.
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %% [markdown]
# ## 📊 Dataset Overview
#
# The dataset includes movies and TV shows available on Netflix, with attributes such as title, director, cast, country, release year, duration, and genre.
# For this project, we'll mainly focus on movies from the 1990s.

# %%
# Importing pandas and matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")
netflix_df
# Out:
#      show_id  ...             genre
# 0         s2  ...            Dramas
# 1         s3  ...     Horror Movies
# 2         s4  ...            Action
# 3         s5  ...            Dramas
# 4         s6  ...  International TV
# ...      ...  ...               ...
# 4807   s7779  ...          Comedies
# 4808   s7781  ...            Dramas
# 4809   s7782  ...          Children
# 4810   s7783  ...            Dramas
# 4811   s7784  ...            Dramas
#
# [4812 rows x 11 columns]

# %% [markdown]
# ## 🎬 Finding Short Action Movies
#
# Let's find out how many action movies released during the 1990s were considered 'short' (less than 90 minutes).

# %%
# Start coding here! Use as many cells as you like
duration = int((netflix_df.loc[(netflix_df['release_year'] >= 1990) & (netflix_df['release_year'] <= 1999), 'duration']).value_counts().idxmax())

short_movie_count = 0
gen_re = netflix_df[netflix_df['genre'] == "Action"]
for lab, row in gen_re.iterrows():
    if row['duration'] < 90 and row['release_year'] in range(1990, 1999):
        short_movie_count += 1

print(f"Number of short Action movies (1990s): {short_movie_count}")
# Out:
# Number of short Action movies (1990s): 7

# %% [markdown]
# ### ✨ Insight
# We found **7 short action movies** from the 1990s, showing that shorter action films were not very common during this decade.

# %% [markdown]
# ## 📅 Movie Releases per Year
#
# Let's visualize the number of movies released each year during the 1990s.

# %%
plt.figure(figsize=(24,10))
sns.countplot(data=netflix_df[netflix_df['release_year'].between(1990, 1999)], 
              x='release_year', palette='viridis')
plt.title("Number of Netflix Movies Released per Year (1990s)")
plt.xlabel("Year")
plt.ylabel("Movie Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ✨ Insight
# Some years had a spike in movie releases. This might reflect Netflix’s acquisition strategy or production trends.

# %% [markdown]
# ## ⏰ Distribution of Movie Durations
#
# Now, let's check the distribution of movie lengths during the 90s.

# %%
plt.figure(figsize=(26,12))
sns.histplot(netflix_df[netflix_df['release_year'].between(1990, 1999)]['duration'], 
             bins=20, kde=True, color = 'seagreen')
plt.title("Distribution of Movie Durations (1990s)")
plt.xlabel("Duration (minutes)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### ✨ Insight
# Most movies tend to have durations around **[100]** minutes, suggesting standard viewer preferences.

# %% [markdown]
# ## 🎭 Top 10 Genres in 1990s Netflix Movies
#
# Which genres ruled the 90s? Let’s find out!

# %%
genre_90s = netflix_df[netflix_df['release_year'].between(1990, 1999)]['genre'].value_counts().head(10)
genre_90s.plot(kind='bar', color='teal', figsize=(24,10))
plt.title("Top 10 Genres (1990s Netflix Movies)")
plt.xlabel("Genre")
plt.ylabel("Number of Movies")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ✨ Insight
# Genres like **[Action - Dramas - Comedies]** dominated the 90s Netflix catalog, reflecting what audiences loved back then.

# %% [markdown]
# # 🏁 Conclusion
#
# Through this exploration, we discovered trends in Netflix's 1990s movie collection, from popular genres to typical movie durations.
# Understanding these patterns is crucial for anyone interested in tapping into nostalgic content styles.
#
# Thank you for exploring with me! 🎬✨
